# %% [markdown]
# <a href="https://colab.research.google.com/github/supreeth-m08/Quantum-random-number-generator/blob/main/project%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask qiskit qiskit-aer matplotlib
# !pip install flask-cloudflared

# %%
import os

folders = ['quantum', 'templates', 'static', 'outputs']

for folder in folders:
    if not os.path.exists(folder):
        os.makedirs(folder)
        print(f"Created folder: {folder}")

print("Project folder structure initialized successfully!")
# Out:
# Project folder structure initialized successfully!

# %%
# %%writefile quantum/bell_states.py
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
import os

def create_bell():
    qc = QuantumCircuit(2, 2)
    qc.h(0)
    qc.cx(0, 1)
    qc.measure([0, 1], [0, 1])
    return qc

def run_circuit(qc):
    simulator = AerSimulator()
    result = simulator.run(qc, shots=1024).result()
    return result.get_counts()

def save_bell_histogram(counts):
    plt.clf()
    plot_histogram(counts)
    os.makedirs('static', exist_ok=True)
    plt.savefig('static/bell_histogram.png', bbox_inches='tight')
    plt.close()
# Out:
# Overwriting quantum/bell_states.py

# %%
# %%writefile quantum/entanglement.py
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulatornn

def create_entanglement():
    qc = QuantumCircuit(2, 2)
    qc.h(0)
    qc.cx(0, 1)
    qc.measure([0, 1], [0, 1])
    return qc

def run_entanglement(qc):
    simulator = AerSimulator()
    result = simulator.run(qc, shots=1024).result()
    return result.get_counts()
# Out:
# Overwriting quantum/entanglement.py

# %%
# %%writefile templates/index.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#             <title>Quantum Communication Dashboard</title>
#                 <style>
#                         body { font-family: Arial, sans-serif; background: #eef5ff; margin: 40px; text-align: center; }
#                                 .card { background: white; padding: 20px; border-radius: 12px; display: inline-block; width: 250px; margin: 15px; box-shadow: 0 4px 10px rgba(0,0,0,0.1); }
#                                         h1 { color: #1b1b4b; }
#                                                 a { display: inline-block; margin-top: 10px; padding: 10px 20px; background: #0066ff; color: white; text-decoration: none; border-radius: 6px; }
#                                                     </style>
#                                                     </head>
#                                                     <body>
#                                                         <h1>Quantum Communication Dashboard</h1>
#                                                             <p>Simulating quantum communication models directly using Flask & Qiskit Aer.</p>
#
#                                                                     <div class="card">
#                                                                             <h3>Bell States</h3>
#                                                                                     <p>Run 2-qubit maximum entanglement states.</p>
#                                                                                             <a href="/bell">Execute Circuit</a>
#                                                                                                 </div>
#
#                                                                                                     <div class="card">
#                                                                                                             <h3>Entanglement</h3>
#                                                                                                                     <p>Observe correlated measurement outputs.</p>
#                                                                                                                             <a href="/entanglement">Execute Circuit</a>
#                                                                                                                                 </div>
#
#                                                                                                                                     <div class="card">
#                                                                                                                                             <h3>Teleportation</h3>
#                                                                                                                                                     <p>Observe 3-qubit state mapping.</p>
#                                                                                                                                                             <a href="/teleportation">Execute Circuit</a>
#                                                                                                                                                                 </div>
#                                                                                                                                                                 </body>
#                                                                                                                                                                 </html>
# Out:
# Overwriting templates/index.html

# %%
# %%writefile quantum/teleportation.py
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

def create_teleportation():
    qc = QuantumCircuit(3, 3)
    qc.h(0)
    qc.h(1)
    qc.cx(1, 2)
    qc.cx(0, 1)
    qc.h(0)
    qc.measure([0, 1, 2], [0, 1, 2])
    return qc
def run_teleportation(qc):
    simulator = AerSimulator()
    result = simulator.run(qc, shots=1024).result()
    return result.get_counts()
# Out:
# Overwriting quantum/teleportation.py

# %%
# %%writefile app.py
from flask import Flask, render_template, jsonify
from quantum.bell_states import create_bell, run_circuit
from quantum.entanglement import create_entanglement, run_entanglement
from quantum.teleportation import create_teleportation, run_teleportation

app = Flask(__name__)

@app.route("/")
def home():
    return render_template("index.html")

@app.route("/bell")
def bell():
    qc = create_bell()
    counts = run_circuit(qc)
    return f"<h3>Bell States Measurement Histograms Counts:</h3><pre>{str(counts)}</pre><br><a href='/'>Back to Dashboard</a>"

@app.route("/entanglement")
def entanglement():
    qc = create_entanglement()
    counts = run_entanglement(qc)
    return f"<h3>Entanglement Correlation Distribution Output:</h3><pre>{str(counts)}</pre><br><a href='/'>Back to Dashboard</a>"

@app.route("/teleportation")
def teleportation():
    qc = create_teleportation()
    counts = run_teleportation(qc)
    return f"<h3>Teleportation State Vector Mapping Distribution Counts:</h3><pre>{str(counts)}</pre><br><a href='/'>Back to Dashboard</a></h3>
if __name__ == "__main__"
                                            # Running locally inside colab environment ecosystem
    app.run()
# Out:
# Overwriting app.py

# %%
from flask_cloudflared import run_with_cloudflared
from app import app

# Apply secure cloudflare tunneling configurations to expose port 5000 automatically
run_with_cloudflared(app)

if __name__ == "__main__":
    app.run()
# Out:
#  * Starting Cloudflared tunnel...
#  * Starting Cloudflared tunnel...
#  * Serving Flask app 'app'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Updating cloudflared for Linux x86_64...
#  * Updating cloudflared for Linux x86_64...
#  * Cloudflared updated successfully
#  * Cloudflared updated successfully
#  * Running on https://database-vancouver-bigger-framing.trycloudflare.com
#  * Traffic stats available on http://127.0.0.1:8444/metrics
#  * Running on https://icq-pursue-inherited-projector.trycloudflare.com
#  * Traffic stats available on http://127.0.0.1:8343/metrics
